# %%
import numpy as np
path = "data/gridrobot_1960.npz"
data = np.load(path)
for key in data.keys():
    print(key)
# Out:
# trajs
# features
# rewards
# theta
# beta
# pref_pairs
# pref_labels
# triplets
# triplet_labels

# %%
data["trajs"].shape
# Out:
# (1960, 19)

# %%
data["features"].shape
# Out:
# (1960, 2)
