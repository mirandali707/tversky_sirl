# %%
import numpy as np
path = "data/gridworld_120.npz"
data = np.load(path)
for key in data.keys():
    print(key)
# Out:
# trajs
# features
# rewards
# theta
# beta
# pref_pairs
# pref_labels
# triplets
# triplet_labels

# %%
data["trajs"].shape
# Out:
# (120, 18)

# %%
data["features"].shape
# Out:
# (120, 4)

# %%
data["triplets"].shape
# Out:
# (200, 3)
