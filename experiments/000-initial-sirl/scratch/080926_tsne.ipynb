# %%
# CHECKPOINT!
import sys
sys.path.insert(0, '../src')
from utils import *
from tversky_sirl import *
OUT_DIR = "../results/tversky_feats_results"
model = load_model(f"{OUT_DIR}/tversky_4.pth")
# Out:
# pybullet build time: Oct 21 2025 16:30:45

# %%
model
# Out:
# TverskySIRL(
#   (encoder): Sequential(
#     (0): Linear(in_features=567, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=1024, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=1024, out_features=6, bias=True)
#   )
#   (tversky_sim): TverskySimilarity(
#     (feature_bank): Embedding(4, 6)
#   )
# )

# %%
all_trajs = load_all_trajs()
all_features = get_features(all_trajs, all_trajs)
# Out:
# all_trajs shape: (10000, 21, 97)
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,152]:
# URDF file 'table/table.urdf' not found
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 2
#       1 all_trajs = load_all_trajs()
# ----> 2 all_features = get_features(all_trajs, all_trajs)
#
# File ~/code/mit/summer26/ahri/tversky_sirl/experiments/000-initial-sirl/scratch/../src/utils.py:89, in get_features(all_trajs, traj_list)
#      70 env_params = {
#      71     "type": "jacorobot",
#      72     "resources_dir": "../data/resources",
#    (...)     80     "input_dict": {'lowdim': False, 'EErot': False, 'noxyz': False, 'norot': True, 'noangles': True}
#      81 }
#      82 human_params = {
#      83     "type": "jacorobot",
#      84     # "features": ["table", "coffee", "laptop", "proxemics"],
#      85     "features": ["table", "laptop"],
# ...

# %%
    # all_sim = tversky_sim.similarity(torch.tensor(all_trajs, dtype=torch.float32), torch.tensor(all_trajs, dtype=torch.float32))
