# %%
from models import load_model
from utils import *

# TODO this is a horrible way of doing this lol
# had to manually create config file.. makes no sense and the paths are all relative
# load_model should take train config + path to ckpt instead
config = parse_config('../configs/tversky_sirl_eval.yaml')
model, ckpt_path = load_model(config) # wtf lol why am i returning ckpt path

# TODO eventually loop all *tversky* ckpts

# %%
model
# Out:
# TverskySIRL(
#   (encoder): Sequential(
#     (0): Linear(in_features=19, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=10, bias=True)
#   )
#   (tversky_sim): TverskySimilarity(
#     (feature_bank): Embedding(4, 10)
#   )
# )

# %%
feature_bank = model.tversky_sim.feature_bank.weight.detach()
feature_bank.shape # 4 Tversky features, of 6-dim embeddings
# Out:
# torch.Size([4, 10])
